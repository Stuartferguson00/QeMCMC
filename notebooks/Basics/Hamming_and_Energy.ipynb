# %% [markdown]
# This notebook recreates the graphs in Fig. 5 of the paper by Layden et al. See paper for context

# %%
# imports
import itertools
import matplotlib.pyplot as plt
import numpy as np
import tqdm
import joblib

# imports from qemcmc
from qemcmc.model import EnergyModel, ModelMaker
from qemcmc.sampler import QeProposal, ClassicalProposal
from qemcmc.coarse_grain import CoarseGraining

# %%
# Define parameters
n_spins = 6  # Number of spins in the system
# Initialise a random fully connected Ising model
model  = ModelMaker(n_spins, "Fully Connected Ising", "example model").model
#model = ModelMaker(n_spins, "Fully Connected QUBO", "example model").model

# %% [markdown]
# # Classically calculate some useful quantifies

# %%
# (Classically) calculate energies of all configurations
all_energies = model.get_all_energies()


# (Classically) calculate the energy differences for all pairs of configurations
# And the Hamming distances for all pairs of configurations
S = np.array([np.binary_repr(s, width=n_spins) for s in range(2**n_spins)])
S_integer_arr = np.array([[int(bit) for bit in state] for state in S])
E_s = np.array(all_energies)

# find matrices of Energy differences of the configyurations, and hamming distances
E_diffs = np.zeros((2**n_spins, 2**n_spins))
hamming_dists = np.zeros((2**n_spins, 2**n_spins))
for s in S:
    for s_prime in S:
        hamming_dist = np.sum(np.bitwise_xor(S_integer_arr[int(s, 2)], S_integer_arr[int(s_prime, 2)]))
        E_diff = abs(E_s[int(s, 2)] - E_s[int(s_prime, 2)])
        E_diffs[int(s, 2), int(s_prime, 2)] = E_diff
        hamming_dists[int(s, 2), int(s_prime, 2)] = hamming_dist

E_order = np.argsort(E_s)

# %% [markdown]
# # Simulate classical proposals
#
# Instead of using classical_mcmc, we quickly generate the proposal distruibutions manually

# %%
# How many times to sample each proposal
reps = 1000

uniform_proposal = ClassicalProposal(model,method = "uniform")
uniform_weights = np.zeros_like(E_diffs)
self_proposals = 0
for i, s in enumerate(tqdm.tqdm(S)):
    for j in range(reps):
        state = uniform_proposal.update(s)
        state_int = int(state, 2)
        uniform_weights[i, state_int] += 1
uniform_weights = uniform_weights / (reps)
uniform_weights_ordered = uniform_weights[E_order, :][:, E_order]




plt.hist2d(np.repeat(np.arange(2**n_spins), 2**n_spins), np.tile(np.arange(2**n_spins), 2**n_spins), bins=2**n_spins, weights=uniform_weights_ordered.flatten())#, norm="log")
plt.title("Uniform MCMC proposal weights heatmap")
plt.xlabel("s")
plt.ylabel("s'")
plt.colorbar(label="Proposal weight")
plt.show()
# Out:
# 100%|██████████| 64/64 [00:01<00:00, 49.28it/s]

# %%
# How many times to sample each proposal
reps = 1000
local_proposal = ClassicalProposal(model, method = "local")
local_weights = np.zeros_like(E_diffs)
self_proposals = 0
for i, s in enumerate(tqdm.tqdm(S)):
    for j in range(reps):
        state = local_proposal.update(s)
        state_int = int(state, 2)
        local_weights[i, state_int] += 1
local_weights = local_weights / (reps)
local_weights_ordered = local_weights[E_order, :][:, E_order]




plt.hist2d(np.repeat(np.arange(2**n_spins), 2**n_spins), np.tile(np.arange(2**n_spins), 2**n_spins), bins=2**n_spins, weights=local_weights_ordered.flatten())#, norm="log")
plt.title("Local MCMC proposal weights heatmap")
plt.xlabel("s")
plt.ylabel("s'")
plt.colorbar(label="Proposal weight")
plt.show()
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 126.48it/s]

# %% [markdown]
# The uniform proposal of course has a very uniform distribution, while the local proposal has a sparse and structured distribution. Note that the configurations are ordered (on both axis) by their energy.
#
# # Quantum-enhanced proposals
#
# Lets see how the quantum proposal distribution looks. To do this, we first take samples using the qe_proposal class.

# %%
# QeMCMC parameters
gamma = 0.45
time = 10
# How many times to sample each proposal
reps = 5

quantum_proposal = QeProposal(model, gamma=gamma, time=time)

# %%
# brute force method to get QeMCMC weights
qemcmc_weights_brute = np.zeros_like(E_diffs)
self_proposals = 0
for i, s in enumerate(tqdm.tqdm(S)):
    for j in range(reps):
        state = quantum_proposal.update(s)
        state_int = int(state, 2)
        qemcmc_weights_brute[i, state_int] += 1
qemcmc_weights_brute = qemcmc_weights_brute / (reps)

qemcmc_weights_brute_ordered = qemcmc_weights_brute[E_order, :][:, E_order]
# make the color graident logarithmic
plt.hist2d(np.repeat(np.arange(2**n_spins), 2**n_spins), np.tile(np.arange(2**n_spins), 2**n_spins), bins=2**n_spins, weights=qemcmc_weights_brute_ordered.flatten(), norm="log")
plt.title("QeMCMC proposal weights heatmap")
plt.xlabel("s")
plt.ylabel("s'")
plt.colorbar(label="Proposal weight")
plt.show()
# Out:
# 100%|██████████| 64/64 [00:13<00:00,  4.81it/s]

# %% [markdown]
# The distribution is very structured around the diagonal, suggesting proposals of small energy change are higher in probability. The graph is very sparse however, so lets extract exact statevectors so that we can better understand the proposal.

# %%
time = 10
qemcmc_weights = np.zeros_like(E_diffs)
for i, s in enumerate(tqdm.tqdm(S)):
    probabilities = np.abs(quantum_proposal.CM.get_state_vector(s, np.ones(len(quantum_proposal.coupling_weights))*(1-gamma), time, 10,gamma)) ** 2
    qemcmc_weights[int(i),:] += probabilities


qemcmc_weights_ordered = qemcmc_weights[E_order, :][:, E_order]


plt.hist2d(np.repeat(np.arange(2**n_spins), 2**n_spins), np.tile(np.arange(2**n_spins), 2**n_spins), bins=2**n_spins, weights=qemcmc_weights_ordered.flatten(), norm="log")
plt.title("QeMCMC proposal weights heatmap")
plt.xlabel("s")
plt.ylabel("s'")
plt.colorbar(label="Proposal weight")
# plt.show()
self_proposals_percent = (100 * np.sum(np.diag(qemcmc_weights))) / (reps * (2**n_spins))

# normalise
row_sums = qemcmc_weights.sum(axis=1)
qemcmc_weights = qemcmc_weights / row_sums[:, np.newaxis]
# Out:
# 100%|██████████| 64/64 [00:01<00:00, 46.06it/s]

# %% [markdown]
# # Hamming weight plot
#
# Plot cumulative hamming weight of each proposal to compare

# %%
row_sums_brute = qemcmc_weights_brute.sum(axis=1)
qemcmc_weights_brute = qemcmc_weights_brute / row_sums_brute[:, np.newaxis]

# plot histograms of hamming distances
weights_list = [local_weights, uniform_weights, qemcmc_weights_brute, qemcmc_weights]
labels = ["local", "uniform", "QeMCMC_brute", "QeMCMC"]
for weights, label in zip(weights_list, labels):
    plt.hist(hamming_dists.flatten(), bins=2**n_spins, weights=weights.flatten(), density=False, histtype="step", cumulative=True, label=label + "_hamming_dist")
    # plt.hist(E_diffs.flatten(), bins = n_spins, weights = weights.flatten(), density=True, histtype="step",
    #         cumulative=True, label=label+"_Energy_difference")
plt.legend()
plt.title("Hamming distance cummulative")
plt.xlabel("Hamming distance")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# # Energy difference plot
#
# Plot cumulative hamming weight of proposals

# %%
# plot energy difference histograms 
for weights, label in zip(weights_list, labels):
    plt.hist(E_diffs.flatten(), bins=2 ** (n_spins), weights=weights.flatten(), density=False, histtype="step", cumulative=True, label=label + "_Energy_difference")
plt.legend()
plt.title("Energy difference cummulative")
plt.xlabel("Energy difference")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# # Bonus
#
# Recreating the same graphs, but with coarse graining. This is a lot harder to do while "cheating" with the statevector approach, so instead we will just sample.

# %%
# How many times to sample each proposal
reps = 10

# 2 sub groups
m = 2
print("maximum qubits used:", np.ceil(n_spins / m))

# brute force method to get QeMCMC weights
quantum_proposal = QeProposal(model, gamma=gamma, time=time, m = m)
qemcmc_weights_brute_2 = np.zeros_like(E_diffs)
self_proposals = 0
for i, s in enumerate(tqdm.tqdm(S)):
    for j in range(reps):
        state = quantum_proposal.update(s)
        state_int = int(state, 2)
        qemcmc_weights_brute_2[i, state_int] += 1
qemcmc_weights_brute_2 = qemcmc_weights_brute_2 / (reps)

qemcmc_weights_brute_ordered_2 = qemcmc_weights_brute_2[E_order, :][:, E_order]
# make the color graident logarithmic
plt.hist2d(np.repeat(np.arange(2**n_spins), 2**n_spins), np.tile(np.arange(2**n_spins), 2**n_spins), bins=2**n_spins, weights=qemcmc_weights_brute_ordered_2.flatten(), norm="log")
plt.title("QeMCMC proposal weights heatmap")
plt.xlabel("s")
plt.ylabel("s'")
plt.colorbar(label="Proposal weight")
plt.show()
# Out:
# maximum qubits used: 3.0
#  53%|█████▎    | 34/64 [00:13<00:12,  2.47it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19740\2028997492.py in <cell line: 0>()
#      12 for i, s in enumerate(tqdm.tqdm(S)):
#      13     for j in range(reps):
# ---> 14         state = quantum_proposal.update(s)
#      15         state_int = int(state, 2)
#      16         qemcmc_weights_brute_2[i, state_int] += 1
#
# ~\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\src\qemcmc\sampler\qe_proposal.py in update(self, current_state)
#     133             # Recalculate local couplings as spins outside the subgroup may have flipped
#     134             local_couplings = self.model.get_subgroup_couplings(subgroup=subgroup, current_state=working_state, coupling_weights=final_coupling_weights)
# --> 135             working_state = self.CM.update(s=working_state, subgroup_choice=subgroup, local_couplings=local_couplings, gamma=g, time=t, r=r)
#     136         return working_state
#     137
#
# ~\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\src\qemcmc\circuits.py in update(self, s, subgroup_choice, local_couplings, gamma, time, r)
#     322         # Get s_cg' for the subgroup and reconstruct full s' using s and s_cg'
#     323         s_cg = "".join([s[i] for i in subgroup_choice])
# --> 324         s_cg_prime = self.get_sample(s_cg, time, r, gamma, local_couplings)
#     325         s_list = list(s)
#     326         for i, global_index in enumerate(subgroup_choice):
#
# ~\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\src\qemcmc\circuits.py in get_sample(self, s_cg, time, r, mix_weight, local_couplings, weights)
#     287         # Get the first shot from the sample
#     288         compiled_circuit = qml.compile(quantum_evolution)
# --> 289         sample = compiled_circuit(s_cg)[0]
#     290         # sample = quantum_evolution(s_cg)[0]
#     291         bitstring = "".join(str(int(b)) for b in sample)
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\workflow\qnode.py in __call__(self, *args, **kwargs)
#     861
#     862             return capture_qnode(self, *args, **kwargs)
# --> 863         return self._impl_call(*args, **kwargs)
#     864
#     865
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\workflow\qnode.py in _impl_call(self, *args, **kwargs)
#     834         self._transform_program.set_classical_component(self, args, kwargs)
#     835
# --> 836         res = execute(
#     837             (tape,),
#     838             device=self.device,
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\workflow\execution.py in execute(tapes, device, diff_method, interface, grad_on_execution, cache, cachesize, max_diff, device_vjp, postselect_mode, mcm_method, gradient_kwargs, transform_program, executor_backend)
#     229     config = _resolve_execution_config(config, device, tapes)
#     230
# --> 231     outer_transform, inner_transform = _setup_transform_program(device, config, cache, cachesize)
#     232
#     233     #### Executing the configured setup #####
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\workflow\_setup_transform_program.py in _setup_transform_program(device, resolved_execution_config, cache, cachesize)
#      51     """
#      52
# ---> 53     device_transform_program = device.preprocess_transforms(resolved_execution_config)
#      54
#      55     outer_transform_program = CompilePipeline()
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane_lightning\lightning_qubit\lightning_qubit.py in preprocess_transforms(self, execution_config)
#     402         pipeline.add_transform(validate_device_wires, self.wires, name=self.name)
#     403         if exec_config.mcm_config.mcm_method == "one-shot":
# --> 404             pipeline.add_transform(
#     405                 dynamic_one_shot, postselect_mode=exec_config.mcm_config.postselect_mode
#     406             )
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\transforms\core\compile_pipeline.py in add_transform(self, transform, *targs, **tkwargs)
#     477         if not isinstance(transform, Transform):
#     478             raise TransformError("Only transforms can be added to the compile pipeline.")
# --> 479         self.append(BoundTransform(transform, args=targs, kwargs=tkwargs))
#     480
#     481     def insert(self, index: int, transform: Transform | BoundTransform):
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\transforms\core\compile_pipeline.py in append(self, transform)
#     440
#     441         with _exclude_terminal_transform(self._compile_pipeline):
# --> 442             if expand_transform := transform.expand_transform:
#     443                 self._compile_pipeline.append(expand_transform)
#     444             self._compile_pipeline.append(transform)
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\transforms\core\transform_dispatcher.py in expand_transform(self)
#     900         if not self._transform.expand_transform:
#     901             return None
# --> 902         return BoundTransform(
#     903             self._transform.expand_transform,
#     904             args=self.args,
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\transforms\core\transform_dispatcher.py in __init__(self, transform, args, kwargs, use_argnum, **transform_config)
#     841     ):
#     842         if not isinstance(transform, Transform):
# --> 843             transform = Transform(transform, **transform_config)
#     844         elif transform_config:
#     845             raise ValueError(
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\transforms\core\transform_dispatcher.py in __init__(self, tape_transform, pass_name, expand_transform, classical_cotransform, is_informative, final_transform, use_argnum_in_expand, plxpr_transform)
#     557
#     558         self._apply_transform = singledispatch(partial(specific_apply_transform, self))
# --> 559         self._plxpr_transform = plxpr_transform or _create_plxpr_fallback_transform(tape_transform)
#     560
#     561     @property
#
# c:\Users\Stuart Ferguson\OneDrive - University of Edinburgh\Documents\PhD\CODE\QeMCMC\QeMCMC\.venv\Lib\site-packages\pennylane\transforms\core\transform_dispatcher.py in _create_plxpr_fallback_transform(tape_transform)
#      63     # pylint: disable=import-outside-toplevel
#      64     try:
# ---> 65         import jax
#      66
#      67         from pennylane.tape import plxpr_to_tape
#
# ~\AppData\Roaming\uv\python\cpython-3.13.3-windows-x86_64-none\Lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Roaming\uv\python\cpython-3.13.3-windows-x86_64-none\Lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\AppData\Roaming\uv\python\cpython-3.13.3-windows-x86_64-none\Lib\importlib\_bootstrap.py in _find_spec(name, path, target)
#
# ~\AppData\Roaming\uv\python\cpython-3.13.3-windows-x86_64-none\Lib\importlib\_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# ~\AppData\Roaming\uv\python\cpython-3.13.3-windows-x86_64-none\Lib\importlib\_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# ~\AppData\Roaming\uv\python\cpython-3.13.3-windows-x86_64-none\Lib\importlib\_bootstrap_external.py in find_spec(self, fullname, target)
#
# ~\AppData\Roaming\uv\python\cpython-3.13.3-windows-x86_64-none\Lib\importlib\_bootstrap_external.py in _path_stat(path)
#
# KeyboardInterrupt:

# %%
# How many times to sample each proposal
reps = 10

# 4 sub groups
m = 4
print("maximum qubits used:", np.ceil(n_spins / m))

# brute force method to get QeMCMC weights
quantum_proposal = QeProposal(model, gamma=gamma, time=time, m = m)
qemcmc_weights_brute_3 = np.zeros_like(E_diffs)
self_proposals = 0
for i, s in enumerate(tqdm.tqdm(S)):
    for j in range(reps):
        state = quantum_proposal.update(s)
        state_int = int(state, 2)
        qemcmc_weights_brute_3[i, state_int] += 1
qemcmc_weights_brute_3 = qemcmc_weights_brute_3 / (reps)

qemcmc_weights_brute_ordered_2 = qemcmc_weights_brute_3[E_order, :][:, E_order]
# make the color graident logarithmic
plt.hist2d(np.repeat(np.arange(2**n_spins), 2**n_spins), np.tile(np.arange(2**n_spins), 2**n_spins), bins=2**n_spins, weights=qemcmc_weights_brute_ordered_2.flatten(), norm="log")
plt.title("QeMCMC proposal weights heatmap")
plt.xlabel("s")
plt.ylabel("s'")
plt.colorbar(label="Proposal weight")
plt.show()
# Out:
# maximum qubits used: 2.0
# 100%|██████████| 64/64 [00:48<00:00,  1.31it/s]

# %%
cg_weights_list = [local_weights, uniform_weights, qemcmc_weights_brute, qemcmc_weights_brute_2, qemcmc_weights_brute_3]
cg_labels = ["local", "uniform", f"Q {n_spins} qubits", f"Q {int(np.ceil(n_spins/2))} qubits", f"Q {int(np.ceil(n_spins/4))} qubits"]

for weights, label in zip(cg_weights_list, cg_labels):
    plt.hist(hamming_dists.flatten(), bins=2**n_spins, weights=weights.flatten(), density=False, histtype="step", cumulative=True, label=label + "_hamming_dist")
    # plt.hist(E_diffs.flatten(), bins = n_spins, weights = weights.flatten(), density=True, histtype="step",
    #         cumulative=True, label=label+"_Energy_difference")
plt.legend()
plt.title("Hamming distance cummulative")
plt.xlabel("Hamming distance")
plt.ylabel("counts")
plt.show()

# %%
# plot energy difference histograms with area under curve for each method
for weights, label in zip(cg_weights_list, cg_labels):
    plt.hist(E_diffs.flatten(), bins=2 ** (n_spins), weights=weights.flatten(), density=False, histtype="step", cumulative=True, label=label + "_Energy_difference")
plt.legend()
plt.title("Energy difference cummulative")
plt.xlabel("Energy difference")
plt.ylabel("counts")
plt.show()
